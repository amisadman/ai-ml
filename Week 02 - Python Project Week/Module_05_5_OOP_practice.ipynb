# %% [markdown]
# 1.  Make three classes:
# Phone → has model and battery (default 100).
#
#
# SmartPhone → inherits from Phone and adds operating system.
#
#
# GamingPhone  → inherits from SmartPhone and adds cooling_system.
#  Add a method start_game(name) that prints
#    "Playing <name> on <model>".

# %%
class Phone:
  def __init__(self,model,battery = 100):
    self.model = model

class SmartPhone(Phone):
  def __init__(self, model,os):
    super().__init__(model)
    self.os = os

class GamingPhone(SmartPhone):
  def __init__(self, model, os, cooling_system):
    super().__init__(model, os)
    self.cooling_system = cooling_system

  def start_game(self, name):
    print(f"Playing {name} on {self.model}")

# %%
gp = GamingPhone("G", "android", "liquid")

gp.start_game("mc5")
# Out:
# Playing mc5 on G

# %% [markdown]
# 2. Make a class MobilePhone with:
# model (public)
#
#
# __battery (private, default 100)
#  Add methods:
#
#
# use() → reduce battery
#
#
# charge() → increase battery (max 100)
#
#
# get_battery() → show battery

# %%
class MobilePhone:
  def __init__(self, model , battery = 100):
    self.model = model
    self.__battery = battery

  def get_battery(self):
    return self.__battery
  def use(self):
    self.__battery -= 10

  def charge(self):
    self.__battery = 100

# %%
mp = MobilePhone("Walton b23")

mp.get_battery()
# Out:
# 100

# %%
mp.use()
mp.get_battery()
# Out:
# 90

# %%
mp.charge()
mp.get_battery()
# Out:
# 100
